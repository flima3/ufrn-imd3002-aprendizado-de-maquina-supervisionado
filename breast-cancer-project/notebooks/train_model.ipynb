# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.metrics import (accuracy_score,
                             classification_report,
                             precision_score)
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline


from src.config import DADOS_TRATADOS, RANDOM_STATE
  
sns.set_theme(palette='bright')

# %%
# Carregamento da base de dados
df = pd.read_csv(DADOS_TRATADOS)
df.head(2)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
#
#    worst symmetry  worst fractal dimension  diagnosis
# ...

# %%
# Divisão entre features e target
X = df.drop(columns='diagnosis')
y = df['diagnosis']

# Divisão entre conjunto de treino e de teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Normalização das features
X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# %% [markdown]
# ### Primeira análise com Random Forest

# %%
# Criação do classificador
clf = RandomForestClassifier(random_state=RANDOM_STATE)

# Ajuste aos dados
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predição no conjunto de teste
y_pred = clf.predict(X_test)

# Definição das métricas de avaliação do modello
scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted']

# Validação cruzada dos resultados obtidos
results = cross_validate(clf, X, y, cv=5, scoring=scoring)

# Visualização da média das métricas obtidas na validação cruzada
print("Média das métricas:")
for m in scoring:
    print(f"{m}: {np.mean(results['test_' + m]): .4f}")
# Out:
# Média das métricas:
# accuracy:  0.9561
# precision_weighted:  0.9568
# recall_weighted:  0.9561
# f1_weighted:  0.9559

# %% [markdown]
# ### Segunda análise com KNN

# %%
# Criação do classificador
clf = KNeighborsClassifier(n_neighbors=5)

# Ajuste aos dados
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predição no conjunto de teste
y_pred = clf.predict(X_test)

# Definição das métricas de avaliação do modello
scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted']

# Validação cruzada dos resultados obtidos
results = cross_validate(clf, X, y, cv=5, scoring=scoring)

# Visualização da média das métricas obtidas na validação cruzada
print("Média das métricas:")
for m in scoring:
    print(f"{m}: {np.mean(results['test_' + m]): .4f}")
# Out:
# Média das métricas:
# accuracy:  0.9279
# precision_weighted:  0.9295
# recall_weighted:  0.9279
# f1_weighted:  0.9272

# %% [markdown]
# ### Terceira análise com Naive Bayes

# %%
# Criação do classificador
clf = GaussianNB()

# Ajuste aos dados
clf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Predição no conjunto de teste
y_pred = clf.predict(X_test)

# Definição das métricas de avaliação do modello
scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted']

# Validação cruzada dos resultados obtidos
results = cross_validate(clf, X, y, cv=5, scoring=scoring)

# Visualização da média das métricas obtidas na validação cruzada
print("Média das métricas:")
for m in scoring:
    print(f"{m}: {np.mean(results['test_' + m]): .4f}")
# Out:
# Média das métricas:
# accuracy:  0.9385
# precision_weighted:  0.9398
# recall_weighted:  0.9385
# f1_weighted:  0.9380
